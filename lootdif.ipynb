# %% [markdown]
# ### Loot Dif
# this is just to compare our pub9 to the infinity 2.0 code base
#
# This is the regex used to extract just the loot groups from a mobile template
#
# ```lootGroups\s?=\s?{(?:[^{}]|({(?:[^{}]|({(?:[^{}]|({[^{}]*}))*}))*}))*},```

# %%
import os
import re
from difflib import Differ

# %%
dOld = 'C:\\Users\\micha\\source\\swg\\MMOCoreORB\\bin\\scripts\\mobile\\'
dNew = 'C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\'
errors = 0

# %%
dfiles = []

def runFiles(npath):
    dlist = os.listdir(npath)    
    for d in dlist:
        if os.path.isfile(npath + "\\" + d):
            try:
                oldy, newy = getFileContents(npath + "\\" + d)
                oldLG = extractLootGroups(oldy)
                newLG = extractLootGroups(newy)
                dfiles.append([npath + "\\" + d, oldLG, newLG])
            except:
                print("oops")
        else:
            runFiles(npath + "\\" + d)

def getFileContents(fname):
    oldFile = fname.replace(dNew,dOld).replace("/", "\\")
    newFile = fname.replace("/", "\\")
    with open(oldFile) as f1:
        f1_text = f1.read()
    with open(newFile) as f2:
        f2_text = f2.read()
    return f1_text, f2_text

def extractLootGroups(fText):
    re_occurences = "lootGroups\s?=\s?{(?:[^{}]|({(?:[^{}]|({(?:[^{}]|({[^{}]*}))*}))*}))*},"
    return re.findall(re_occurences,fText,flags=re.IGNORECASE)

# %%
runFiles(dNew)
# Out:
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops

# %%
cdif = []
for f in dfiles:
    if len(f[1]) != 0 or len(f[2]) != 0:
        if f[1] != f[2]:
            cdif.append(f)

# %%
cdif
# Out:
# [['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\afarathu_brute.lua',
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "pelgo_aqua", chance = 100 * (100000)},\n\t\t\t},\n\t\t\tlootChance = 3 * (100000)\n\t\t}',
#     '{\n\t\t\t\t{group = "pelgo_aqua", chance = 100 * (100000)},\n\t\t\t}',
#     '{group = "pelgo_aqua", chance = 100 * (100000)}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 7000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 7000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000}\n\t\t\t}',
#     '{group = "tailor_components", chance = 1000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\afarathu_cult_bodyguard.lua',
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "pelgo_aqua", chance = 100 * (100000)},\n\t\t\t},\n\t\t\tlootChance = 3 * (100000)\n\t\t}',
#     '{\n\t\t\t\t{group = "pelgo_aqua", chance = 100 * (100000)},\n\t\t\t}',
#     '{group = "pelgo_aqua", chance = 100 * (100000)}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "pelgo_aqua", chance = 100 * (100000)},\n\t\t\t},\n\t\t\tlootChance = 2 * (100000)\n\t\t}',
#     '{\n\t\t\t\t{group = "pelgo_aqua", chance = 100 * (100000)},\n\t\t\t}',
#     '{group = "pelgo_aqua", chance = 100 * (100000)}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\afarathu_cult_follower.lua',
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "pelgo_aqua", chance = 100 * (100000)},\n\t\t\t},\n\t\t\tlootChance = 3 * (100000)\n\t\t}',
#     '{\n\t\t\t\t{group = "pelgo_aqua", chance = 100 * (100000)},\n\t\t\t}',
#     '{group = "pelgo_aqua", chance = 100 * (100000)}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "pelgo_aqua", chance = 100 * (100000)},\n\t\t\t},\n\t\t\tlootChance = 2 * (100000)\n\t\t}',
#     '{\n\t\t\t\t{group = "pelgo_aqua", chance = 100 * (100000)},\n\t\t\t}',
#     '{group = "pelgo_aqua", chance = 100 * (100000)}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\afarathu_cult_leader.lua',
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "pelgo_aqua", chance = 100 * (100000)},\n\t\t\t},\n\t\t\tlootChance = 3 * (100000)\n\t\t}',
#     '{\n\t\t\t\t{group = "pelgo_aqua", chance = 100 * (100000)},\n\t\t\t}',
#     '{group = "pelgo_aqua", chance = 100 * (100000)}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "pelgo_aqua", chance = 100 * (100000)},\n\t\t\t},\n\t\t\tlootChance = 2 * (100000)\n\t\t}',
#     '{\n\t\t\t\t{group = "pelgo_aqua", chance = 100 * (100000)},\n\t\t\t}',
#     '{group = "pelgo_aqua", chance = 100 * (100000)}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\afarathu_cult_zealot.lua',
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "pelgo_aqua", chance = 100 * (100000)},\n\t\t\t},\n\t\t\tlootChance = 3 * (100000)\n\t\t}',
#     '{\n\t\t\t\t{group = "pelgo_aqua", chance = 100 * (100000)},\n\t\t\t}',
#     '{group = "pelgo_aqua", chance = 100 * (100000)}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "pelgo_aqua", chance = 100 * (100000)},\n\t\t\t},\n\t\t\tlootChance = 2 * (100000)\n\t\t}',
#     '{\n\t\t\t\t{group = "pelgo_aqua", chance = 100 * (100000)},\n\t\t\t}',
#     '{group = "pelgo_aqua", chance = 100 * (100000)}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\afarathu_hellion.lua',
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "pelgo_aqua", chance = 100 * (100000)},\n\t\t\t},\n\t\t\tlootChance = 3 * (100000)\n\t\t}',
#     '{\n\t\t\t\t{group = "pelgo_aqua", chance = 100 * (100000)},\n\t\t\t}',
#     '{group = "pelgo_aqua", chance = 100 * (100000)}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "pelgo_aqua", chance = 100 * (100000)},\n\t\t\t},\n\t\t\tlootChance = 2 * (100000)\n\t\t}',
#     '{\n\t\t\t\t{group = "pelgo_aqua", chance = 100 * (100000)},\n\t\t\t}',
#     '{group = "pelgo_aqua", chance = 100 * (100000)}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\afarathu_ruffian.lua',
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "pelgo_aqua", chance = 100 * (100000)},\n\t\t\t},\n\t\t\tlootChance = 3 * (100000)\n\t\t}',
#     '{\n\t\t\t\t{group = "pelgo_aqua", chance = 100 * (100000)},\n\t\t\t}',
#     '{group = "pelgo_aqua", chance = 100 * (100000)}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "pelgo_aqua", chance = 100 * (100000)},\n\t\t\t},\n\t\t\tlootChance = 2 * (100000)\n\t\t}',
#     '{\n\t\t\t\t{group = "pelgo_aqua", chance = 100 * (100000)},\n\t\t\t}',
#     '{group = "pelgo_aqua", chance = 100 * (100000)}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\afarathu_savage.lua',
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "pelgo_aqua", chance = 100 * (100000)},\n\t\t\t},\n\t\t\tlootChance = 2 * (100000)\n\t\t}',
#     '{\n\t\t\t\t{group = "pelgo_aqua", chance = 100 * (100000)},\n\t\t\t}',
#     '{group = "pelgo_aqua", chance = 100 * (100000)}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 7000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 7000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000}\n\t\t\t}',
#     '{group = "tailor_components", chance = 1000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\beldonnas_league_enforcer.lua',
#   [('{\n\t\t\tgroups = \n\t\t\t{\n\t\t\t\t{group = "eta1_armor_group", chance = 10000000},\n\t\t\t},\n\t\t\tlootChance = 8 * (100000), -- 2% chance for this group\n\t\t}',
#     '{\n\t\t\t\t{group = "eta1_armor_group", chance = 10000000},\n\t\t\t}',
#     '{group = "eta1_armor_group", chance = 10000000}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 3000000},\n\t\t\t\t{group = "wearables_common", chance = 2000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000},\n\t\t\t\t{group = "beldonnas_common", chance = 2000000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 3000000},\n\t\t\t\t{group = "wearables_common", chance = 2000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000},\n\t\t\t\t{group = "beldonnas_common", chance = 2000000}\n\t\t\t}',
#     '{group = "beldonnas_common", chance = 2000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\beldonnas_league_marshal.lua',
#   [('{\n\t\t\tgroups = \n\t\t\t{\n\t\t\t\t{group = "eta1_armor_group", chance = 10000000},\n\t\t\t},\n\t\t\tlootChance = 8 * (100000), -- 2% chance for this group\n\t\t}',
#     '{\n\t\t\t\t{group = "eta1_armor_group", chance = 10000000},\n\t\t\t}',
#     '{group = "eta1_armor_group", chance = 10000000}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 3000000},\n\t\t\t\t{group = "wearables_all", chance = 2000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000},\n\t\t\t\t{group = "beldonnas_common", chance = 2000000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 3000000},\n\t\t\t\t{group = "wearables_all", chance = 2000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000},\n\t\t\t\t{group = "beldonnas_common", chance = 2000000}\n\t\t\t}',
#     '{group = "beldonnas_common", chance = 2000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\beldonnas_league_scout.lua',
#   [('{\n\t\t\tgroups = \n\t\t\t{\n\t\t\t\t{group = "eta1_armor_group", chance = 10000000},\n\t\t\t},\n\t\t\tlootChance = 7 * (100000), -- 2% chance for this group\n\t\t}',
#     '{\n\t\t\t\t{group = "eta1_armor_group", chance = 10000000},\n\t\t\t}',
#     '{group = "eta1_armor_group", chance = 10000000}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 3000000},\n\t\t\t\t{group = "wearables_common", chance = 2000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000},\n\t\t\t\t{group = "beldonnas_common", chance = 2000000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 3000000},\n\t\t\t\t{group = "wearables_common", chance = 2000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000},\n\t\t\t\t{group = "beldonnas_common", chance = 2000000}\n\t\t\t}',
#     '{group = "beldonnas_common", chance = 2000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\beldonnas_league_soldier.lua',
#   [('{\n\t\t\tgroups = \n\t\t\t{\n\t\t\t\t{group = "eta1_armor_group", chance = 10000000},\n\t\t\t},\n\t\t\tlootChance = 6 * (100000), -- 2% chance for this group\n\t\t}',
#     '{\n\t\t\t\t{group = "eta1_armor_group", chance = 10000000},\n\t\t\t}',
#     '{group = "eta1_armor_group", chance = 10000000}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 3000000},\n\t\t\t\t{group = "wearables_common", chance = 2000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000},\n\t\t\t\t{group = "beldonnas_common", chance = 2000000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 3000000},\n\t\t\t\t{group = "wearables_common", chance = 2000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000},\n\t\t\t\t{group = "beldonnas_common", chance = 2000000}\n\t\t\t}',
#     '{group = "beldonnas_common", chance = 2000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\drall_abbot.lua',
#   [('{\n\t\t\tgroups = \n\t\t\t{\n\t\t\t\t{group = "eta1_leather_group", chance = 100 * (100000)},\n\t\t\t},\n\t\t\tlootChance = 7 * (100000), -- 2% chance for this group\n\t\t}',
#     '{\n\t\t\t\t{group = "eta1_leather_group", chance = 100 * (100000)},\n\t\t\t}',
#     '{group = "eta1_leather_group", chance = 100 * (100000)}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 7000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 7000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000}\n\t\t\t}',
#     '{group = "tailor_components", chance = 1000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\drall_chieftain.lua',
#   [('{\n\t\t\tgroups = \n\t\t\t{\n\t\t\t\t{group = "eta1_leather_group", chance = 100 * (100000)},\n\t\t\t},\n\t\t\tlootChance = 7 * (100000), -- 2% chance for this group\n\t\t}',
#     '{\n\t\t\t\t{group = "eta1_leather_group", chance = 100 * (100000)},\n\t\t\t}',
#     '{group = "eta1_leather_group", chance = 100 * (100000)}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 7000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 7000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000}\n\t\t\t}',
#     '{group = "tailor_components", chance = 1000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\drall_guard.lua',
#   [('{\n\t\t\tgroups = \n\t\t\t{\n\t\t\t\t{group = "eta1_leather_group", chance = 100 * (100000)},\n\t\t\t},\n\t\t\tlootChance = 7 * (100000), -- 2% chance for this group\n\t\t}',
#     '{\n\t\t\t\t{group = "eta1_leather_group", chance = 100 * (100000)},\n\t\t\t}',
#     '{group = "eta1_leather_group", chance = 100 * (100000)}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 7000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 7000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000}\n\t\t\t}',
#     '{group = "tailor_components", chance = 1000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\drall_master.lua',
#   [('{\n\t\t\tgroups = \n\t\t\t{\n\t\t\t\t{group = "eta1_leather_group", chance = 100 * (100000)},\n\t\t\t},\n\t\t\tlootChance = 7 * (100000), -- 2% chance for this group\n\t\t}',
#     '{\n\t\t\t\t{group = "eta1_leather_group", chance = 100 * (100000)},\n\t\t\t}',
#     '{group = "eta1_leather_group", chance = 100 * (100000)}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 7000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 7000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000}\n\t\t\t}',
#     '{group = "tailor_components", chance = 1000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\drall_monk.lua',
#   [('{\n\t\t\tgroups = \n\t\t\t{\n\t\t\t\t{group = "eta1_leather_group", chance = 100 * (100000)},\n\t\t\t},\n\t\t\tlootChance = 7 * (100000), -- 2% chance for this group\n\t\t}',
#     '{\n\t\t\t\t{group = "eta1_leather_group", chance = 100 * (100000)},\n\t\t\t}',
#     '{group = "eta1_leather_group", chance = 100 * (100000)}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 7000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 7000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000}\n\t\t\t}',
#     '{group = "tailor_components", chance = 1000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\drall_patriot.lua',
#   [('{\n\t\t\tgroups = \n\t\t\t{\n\t\t\t\t{group = "eta1_leather_group", chance = 100 * (100000)},\n\t\t\t},\n\t\t\tlootChance = 7 * (100000), -- 2% chance for this group\n\t\t}',
#     '{\n\t\t\t\t{group = "eta1_leather_group", chance = 100 * (100000)},\n\t\t\t}',
#     '{group = "eta1_leather_group", chance = 100 * (100000)}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 7000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 7000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000}\n\t\t\t}',
#     '{group = "tailor_components", chance = 1000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\drall_patriot_conqueror.lua',
#   [('{\n\t\t\tgroups = \n\t\t\t{\n\t\t\t\t{group = "eta1_leather_group", chance = 100 * (100000)},\n\t\t\t},\n\t\t\tlootChance = 7 * (100000), -- 2% chance for this group\n\t\t}',
#     '{\n\t\t\t\t{group = "eta1_leather_group", chance = 100 * (100000)},\n\t\t\t}',
#     '{group = "eta1_leather_group", chance = 100 * (100000)}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 7000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 7000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000}\n\t\t\t}',
#     '{group = "tailor_components", chance = 1000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\drall_patriot_foot_soldier.lua',
#   [('{\n\t\t\tgroups = \n\t\t\t{\n\t\t\t\t{group = "eta1_leather_group", chance = 100 * (100000)},\n\t\t\t},\n\t\t\tlootChance = 7 * (100000), -- 2% chance for this group\n\t\t}',
#     '{\n\t\t\t\t{group = "eta1_leather_group", chance = 100 * (100000)},\n\t\t\t}',
#     '{group = "eta1_leather_group", chance = 100 * (100000)}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 7000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 7000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000}\n\t\t\t}',
#     '{group = "tailor_components", chance = 1000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\drall_patriot_legionnaire.lua',
#   [('{\n\t\t\tgroups = \n\t\t\t{\n\t\t\t\t{group = "eta1_leather_group", chance = 100 * (100000)},\n\t\t\t},\n\t\t\tlootChance = 7 * (100000), -- 2% chance for this group\n\t\t}',
#     '{\n\t\t\t\t{group = "eta1_leather_group", chance = 100 * (100000)},\n\t\t\t}',
#     '{group = "eta1_leather_group", chance = 100 * (100000)}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 7000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 7000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000}\n\t\t\t}',
#     '{group = "tailor_components", chance = 1000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\flail_boss.lua',
#   [('{\n\t\t\tgroups = \n\t\t\t{\n\t\t\t\t{group = "eta1_cockpit_group", chance = 10000000},\n\t\t\t},\n\t\t\tlootChance = 8 * (100000), \n\t\t}',
#     '{\n\t\t\t\t{group = "eta1_cockpit_group", chance = 10000000},\n\t\t\t}',
#     '{group = "eta1_cockpit_group", chance = 10000000}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 3500000},\n\t\t\t\t{group = "wearables_all", chance = 3000000},\n\t\t\t\t{group = "rifles", chance = 2000000},\n\t\t\t\t{group = "color_crystals", chance = 1000000},\n\t\t\t\t{group = "flail_common", chance = 500000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 3500000},\n\t\t\t\t{group = "wearables_all", chance = 3000000},\n\t\t\t\t{group = "rifles", chance = 2000000},\n\t\t\t\t{group = "color_crystals", chance = 1000000},\n\t\t\t\t{group = "flail_common", chance = 500000}\n\t\t\t}',
#     '{group = "flail_common", chance = 500000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\flail_butcher.lua',
#   [('{\n\t\t\tgroups = \n\t\t\t{\n\t\t\t\t{group = "eta1_cockpit_group", chance = 10000000},\n\t\t\t},\n\t\t\tlootChance = 9 * (100000), \n\t\t}',
#     '{\n\t\t\t\t{group = "eta1_cockpit_group", chance = 10000000},\n\t\t\t}',
#     '{group = "eta1_cockpit_group", chance = 10000000}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 3500000},\n\t\t\t\t{group = "wearables_common", chance = 3000000},\n\t\t\t\t{group = "rifles", chance = 2000000},\n\t\t\t\t{group = "color_crystals", chance = 1000000},\n\t\t\t\t{group = "flail_common", chance = 500000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 3500000},\n\t\t\t\t{group = "wearables_common", chance = 3000000},\n\t\t\t\t{group = "rifles", chance = 2000000},\n\t\t\t\t{group = "color_crystals", chance = 1000000},\n\t\t\t\t{group = "flail_common", chance = 500000}\n\t\t\t}',
#     '{group = "flail_common", chance = 500000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\flail_cutthroat.lua',
#   [('{\n\t\t\tgroups = \n\t\t\t{\n\t\t\t\t{group = "eta1_cockpit_group", chance = 10000000},\n\t\t\t},\n\t\t\tlootChance = 8 * (100000), \n\t\t}',
#     '{\n\t\t\t\t{group = "eta1_cockpit_group", chance = 10000000},\n\t\t\t}',
#     '{group = "eta1_cockpit_group", chance = 10000000}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 3500000},\n\t\t\t\t{group = "wearables_common", chance = 3000000},\n\t\t\t\t{group = "rifles", chance = 2000000},\n\t\t\t\t{group = "color_crystals", chance = 1000000},\n\t\t\t\t{group = "flail_common", chance = 500000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 3500000},\n\t\t\t\t{group = "wearables_common", chance = 3000000},\n\t\t\t\t{group = "rifles", chance = 2000000},\n\t\t\t\t{group = "color_crystals", chance = 1000000},\n\t\t\t\t{group = "flail_common", chance = 500000}\n\t\t\t}',
#     '{group = "flail_common", chance = 500000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\flail_enforcer.lua',
#   [('{\n\t\t\tgroups = \n\t\t\t{\n\t\t\t\t{group = "eta1_cockpit_group", chance = 10000000},\n\t\t\t},\n\t\t\tlootChance = 8 * (100000), \n\t\t}',
#     '{\n\t\t\t\t{group = "eta1_cockpit_group", chance = 10000000},\n\t\t\t}',
#     '{group = "eta1_cockpit_group", chance = 10000000}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 3500000},\n\t\t\t\t{group = "wearables_common", chance = 3000000},\n\t\t\t\t{group = "rifles", chance = 2000000},\n\t\t\t\t{group = "color_crystals", chance = 1000000},\n\t\t\t\t{group = "flail_common", chance = 500000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 3500000},\n\t\t\t\t{group = "wearables_common", chance = 3000000},\n\t\t\t\t{group = "rifles", chance = 2000000},\n\t\t\t\t{group = "color_crystals", chance = 1000000},\n\t\t\t\t{group = "flail_common", chance = 500000}\n\t\t\t}',
#     '{group = "flail_common", chance = 500000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\flail_executioner.lua',
#   [('{\n\t\t\tgroups = \n\t\t\t{\n\t\t\t\t{group = "eta1_cockpit_group", chance = 10000000},\n\t\t\t},\n\t\t\tlootChance = 8 * (100000), \n\t\t}',
#     '{\n\t\t\t\t{group = "eta1_cockpit_group", chance = 10000000},\n\t\t\t}',
#     '{group = "eta1_cockpit_group", chance = 10000000}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 3500000},\n\t\t\t\t{group = "wearables_common", chance = 3000000},\n\t\t\t\t{group = "rifles", chance = 2000000},\n\t\t\t\t{group = "color_crystals", chance = 1000000},\n\t\t\t\t{group = "flail_common", chance = 500000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 3500000},\n\t\t\t\t{group = "wearables_common", chance = 3000000},\n\t\t\t\t{group = "rifles", chance = 2000000},\n\t\t\t\t{group = "color_crystals", chance = 1000000},\n\t\t\t\t{group = "flail_common", chance = 500000}\n\t\t\t}',
#     '{group = "flail_common", chance = 500000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\flail_killer.lua',
#   [('{\n\t\t\tgroups = \n\t\t\t{\n\t\t\t\t{group = "eta1_cockpit_group", chance = 10000000},\n\t\t\t},\n\t\t\tlootChance = 8 * (100000), \n\t\t}',
#     '{\n\t\t\t\t{group = "eta1_cockpit_group", chance = 10000000},\n\t\t\t}',
#     '{group = "eta1_cockpit_group", chance = 10000000}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 3500000},\n\t\t\t\t{group = "wearables_common", chance = 3000000},\n\t\t\t\t{group = "rifles", chance = 2000000},\n\t\t\t\t{group = "color_crystals", chance = 1000000},\n\t\t\t\t{group = "flail_common", chance = 500000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 3500000},\n\t\t\t\t{group = "wearables_common", chance = 3000000},\n\t\t\t\t{group = "rifles", chance = 2000000},\n\t\t\t\t{group = "color_crystals", chance = 1000000},\n\t\t\t\t{group = "flail_common", chance = 500000}\n\t\t\t}',
#     '{group = "flail_common", chance = 500000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\flail_slayer.lua',
#   [('{\n\t\t\tgroups = \n\t\t\t{\n\t\t\t\t{group = "eta1_cockpit_group", chance = 10000000},\n\t\t\t},\n\t\t\tlootChance = 8 * (100000), \n\t\t}',
#     '{\n\t\t\t\t{group = "eta1_cockpit_group", chance = 10000000},\n\t\t\t}',
#     '{group = "eta1_cockpit_group", chance = 10000000}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 3500000},\n\t\t\t\t{group = "wearables_common", chance = 3000000},\n\t\t\t\t{group = "rifles", chance = 2000000},\n\t\t\t\t{group = "color_crystals", chance = 1000000},\n\t\t\t\t{group = "flail_common", chance = 500000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 3500000},\n\t\t\t\t{group = "wearables_common", chance = 3000000},\n\t\t\t\t{group = "rifles", chance = 2000000},\n\t\t\t\t{group = "color_crystals", chance = 1000000},\n\t\t\t\t{group = "flail_common", chance = 500000}\n\t\t\t}',
#     '{group = "flail_common", chance = 500000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\grecks_smuggler.lua',
#   [('{\n\t\t\tgroups =\n\t\t\t{\n\t\t\t\t{group = "slicing_station_group", chance = 100 * (100000)}\n\t\t\t},\n\t\t\tlootChance = 3 * (100000)\n\t\t}',
#     '{\n\t\t\t\t{group = "slicing_station_group", chance = 100 * (100000)}\n\t\t\t}',
#     '{group = "slicing_station_group", chance = 100 * (100000)}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 7000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 7000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000}\n\t\t\t}',
#     '{group = "tailor_components", chance = 1000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\hidden_daggers_leader.lua',
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 2300000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000},\n\t\t\t\t{group = "hidden_dagger_common", chance = 2200000},\n\t\t\t\t{group = "wearables_all", chance = 1000000},\n\t\t\t\t{group = "art_illum6", chance = 1500000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 2300000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000},\n\t\t\t\t{group = "hidden_dagger_common", chance = 2200000},\n\t\t\t\t{group = "wearables_all", chance = 1000000},\n\t\t\t\t{group = "art_illum6", chance = 1500000}\n\t\t\t}',
#     '{group = "art_illum6", chance = 1500000}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 3300000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000},\n\t\t\t\t{group = "hidden_dagger_common", chance = 2700000},\n\t\t\t\t{group = "wearables_all", chance = 1000000},\n\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 3300000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000},\n\t\t\t\t{group = "hidden_dagger_common", chance = 2700000},\n\t\t\t\t{group = "wearables_all", chance = 1000000},\n\n\t\t\t}',
#     '{group = "wearables_all", chance = 1000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\hidden_daggers_lieutenant.lua',
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 4000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000},\n\t\t\t\t{group = "hidden_dagger_common", chance = 2100000},\n\t\t\t\t{group = "art_illum7", chance = 900000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 4000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000},\n\t\t\t\t{group = "hidden_dagger_common", chance = 2100000},\n\t\t\t\t{group = "art_illum7", chance = 900000}\n\t\t\t}',
#     '{group = "art_illum7", chance = 900000}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 4300000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000},\n\t\t\t\t{group = "hidden_dagger_common", chance = 2700000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 4300000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000},\n\t\t\t\t{group = "hidden_dagger_common", chance = 2700000}\n\t\t\t}',
#     '{group = "hidden_dagger_common", chance = 2700000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\lord_nyax.lua',
#   [('{\n\t    \t\tgroups =\n\t\t\t{\n\t\t\t\t{group = "veteran_rewards_810_days", chance = 10000000},\n\t\t\t},\n\t\t\tlootChance = 1000000,\n\t\t}',
#     '{\n\t\t\t\t{group = "veteran_rewards_810_days", chance = 10000000},\n\t\t\t}',
#     '{group = "veteran_rewards_810_days", chance = 10000000}')],
#   [('{\n\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 4000000},\n\t\t\t\t{group = "nyax", chance = 3000000},\n\t\t\t\t{group = "grenades_looted", chance = 1000000},\n\t\t\t\t{group = "armor_attachments", chance = 1000000},\n\t\t\t\t{group = "clothing_attachments", chance = 1000000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 4000000},\n\t\t\t\t{group = "nyax", chance = 3000000},\n\t\t\t\t{group = "grenades_looted", chance = 1000000},\n\t\t\t\t{group = "armor_attachments", chance = 1000000},\n\t\t\t\t{group = "clothing_attachments", chance = 1000000}\n\t\t\t}',
#     '{group = "clothing_attachments", chance = 1000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\meatlump_buffoon.lua',
#   [('{\n\tgroups = {\n\t\t{group = "junk", chance = 3000000},\n\t\t{group = "loot_kit_parts", chance = 1000000},\n\t\t--{group = "color_crystals", chance = 100000},\n\t\t{group = "tailor_components", chance = 500000},\n\t\t{group = "meatlump_common", chance = 2500000},\n\t\t--{group = "armor_attachments", chance = 5000000},\n\t\t{group = "clothing_attachments", chance = 500000},\n\t\t\t\t{group = "art_illum21", chance = 2500000}\n\t}\n}',
#     '{\n\t\t{group = "junk", chance = 3000000},\n\t\t{group = "loot_kit_parts", chance = 1000000},\n\t\t--{group = "color_crystals", chance = 100000},\n\t\t{group = "tailor_components", chance = 500000},\n\t\t{group = "meatlump_common", chance = 2500000},\n\t\t--{group = "armor_attachments", chance = 5000000},\n\t\t{group = "clothing_attachments", chance = 500000},\n\t\t\t\t{group = "art_illum21", chance = 2500000}\n\t}',
#     '{group = "art_illum21", chance = 2500000}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 2900000},\n\t\t\t\t{group = "loot_kit_parts", chance = 1500000},\n\t\t\t\t{group = "color_crystals", chance = 100000},\n\t\t\t\t{group = "tailor_components", chance = 500000},\n\t\t\t\t{group = "meatlump_common", chance = 5000000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 2900000},\n\t\t\t\t{group = "loot_kit_parts", chance = 1500000},\n\t\t\t\t{group = "color_crystals", chance = 100000},\n\t\t\t\t{group = "tailor_components", chance = 500000},\n\t\t\t\t{group = "meatlump_common", chance = 5000000}\n\t\t\t}',
#     '{group = "meatlump_common", chance = 5000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\meatlump_clod.lua',
#   [('{\n\tgroups = {\n\t\t{group = "junk", chance = 4000000},\n\t\t{group = "loot_kit_parts", chance = 1000000},\n\t\t--{group = "color_crystals", chance = 100000},\n\t\t{group = "tailor_components", chance = 500000},\n\t\t{group = "meatlump_common", chance = 3500000},\n\t\t--{group = "armor_attachments", chance = 5000000},\n\t\t{group = "clothing_attachments", chance = 500000},\n\t\t\t\t{group = "art_illum21", chance = 500000}\n\t}\n}',
#     '{\n\t\t{group = "junk", chance = 4000000},\n\t\t{group = "loot_kit_parts", chance = 1000000},\n\t\t--{group = "color_crystals", chance = 100000},\n\t\t{group = "tailor_components", chance = 500000},\n\t\t{group = "meatlump_common", chance = 3500000},\n\t\t--{group = "armor_attachments", chance = 5000000},\n\t\t{group = "clothing_attachments", chance = 500000},\n\t\t\t\t{group = "art_illum21", chance = 500000}\n\t}',
#     '{group = "art_illum21", chance = 500000}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 2900000},\n\t\t\t\t{group = "loot_kit_parts", chance = 1500000},\n\t\t\t\t{group = "color_crystals", chance = 100000},\n\t\t\t\t{group = "tailor_components", chance = 500000},\n\t\t\t\t{group = "meatlump_common", chance = 5000000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 2900000},\n\t\t\t\t{group = "loot_kit_parts", chance = 1500000},\n\t\t\t\t{group = "color_crystals", chance = 100000},\n\t\t\t\t{group = "tailor_components", chance = 500000},\n\t\t\t\t{group = "meatlump_common", chance = 5000000}\n\t\t\t}',
#     '{group = "meatlump_common", chance = 5000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\meatlump_cretin.lua',
#   [('{\n\tgroups = {\n\t\t{group = "junk", chance = 4500000},\n\t\t{group = "loot_kit_parts", chance = 1000000},\n\t\t--{group = "color_crystals", chance = 100000},\n\t\t{group = "tailor_components", chance = 500000},\n\t\t{group = "meatlump_common", chance = 3500000},\n\t\t--{group = "armor_attachments", chance = 5000000},\n\t\t{group = "clothing_attachments", chance = 500000},\n\t}\n}',
#     '{\n\t\t{group = "junk", chance = 4500000},\n\t\t{group = "loot_kit_parts", chance = 1000000},\n\t\t--{group = "color_crystals", chance = 100000},\n\t\t{group = "tailor_components", chance = 500000},\n\t\t{group = "meatlump_common", chance = 3500000},\n\t\t--{group = "armor_attachments", chance = 5000000},\n\t\t{group = "clothing_attachments", chance = 500000},\n\t}',
#     '{group = "clothing_attachments", chance = 500000}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 2900000},\n\t\t\t\t{group = "loot_kit_parts", chance = 1500000},\n\t\t\t\t{group = "color_crystals", chance = 100000},\n\t\t\t\t{group = "tailor_components", chance = 500000},\n\t\t\t\t{group = "meatlump_common", chance = 5000000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 2900000},\n\t\t\t\t{group = "loot_kit_parts", chance = 1500000},\n\t\t\t\t{group = "color_crystals", chance = 100000},\n\t\t\t\t{group = "tailor_components", chance = 500000},\n\t\t\t\t{group = "meatlump_common", chance = 5000000}\n\t\t\t}',
#     '{group = "meatlump_common", chance = 5000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\meatlump_fool.lua',
#   [('{\n\tgroups = {\n\t\t{group = "junk", chance = 3000000},\n\t\t{group = "loot_kit_parts", chance = 1000000},\n\t\t--{group = "color_crystals", chance = 100000},\n\t\t{group = "tailor_components", chance = 500000},\n\t\t{group = "meatlump_common", chance = 3500000},\n\t\t--{group = "armor_attachments", chance = 5000000},\n\t\t{group = "clothing_attachments", chance = 500000},\n\t\t\t\t{group = "art_illum21", chance = 1500000}\n\t}\n}',
#     '{\n\t\t{group = "junk", chance = 3000000},\n\t\t{group = "loot_kit_parts", chance = 1000000},\n\t\t--{group = "color_crystals", chance = 100000},\n\t\t{group = "tailor_components", chance = 500000},\n\t\t{group = "meatlump_common", chance = 3500000},\n\t\t--{group = "armor_attachments", chance = 5000000},\n\t\t{group = "clothing_attachments", chance = 500000},\n\t\t\t\t{group = "art_illum21", chance = 1500000}\n\t}',
#     '{group = "art_illum21", chance = 1500000}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 2900000},\n\t\t\t\t{group = "loot_kit_parts", chance = 1500000},\n\t\t\t\t{group = "color_crystals", chance = 100000},\n\t\t\t\t{group = "tailor_components", chance = 500000},\n\t\t\t\t{group = "meatlump_common", chance = 5000000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 2900000},\n\t\t\t\t{group = "loot_kit_parts", chance = 1500000},\n\t\t\t\t{group = "color_crystals", chance = 100000},\n\t\t\t\t{group = "tailor_components", chance = 500000},\n\t\t\t\t{group = "meatlump_common", chance = 5000000}\n\t\t\t}',
#     '{group = "meatlump_common", chance = 5000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\meatlump_loon.lua',
#   [('{\n\tgroups = {\n\t\t{group = "junk", chance = 4500000},\n\t\t{group = "loot_kit_parts", chance = 1000000},\n\t\t--{group = "color_crystals", chance = 100000},\n\t\t{group = "tailor_components", chance = 500000},\n\t\t{group = "meatlump_common", chance = 3500000},\n\t\t--{group = "armor_attachments", chance = 5000000},\n\t\t{group = "clothing_attachments", chance = 500000},\n\t}\n}',
#     '{\n\t\t{group = "junk", chance = 4500000},\n\t\t{group = "loot_kit_parts", chance = 1000000},\n\t\t--{group = "color_crystals", chance = 100000},\n\t\t{group = "tailor_components", chance = 500000},\n\t\t{group = "meatlump_common", chance = 3500000},\n\t\t--{group = "armor_attachments", chance = 5000000},\n\t\t{group = "clothing_attachments", chance = 500000},\n\t}',
#     '{group = "clothing_attachments", chance = 500000}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 2900000},\n\t\t\t\t{group = "loot_kit_parts", chance = 1500000},\n\t\t\t\t{group = "color_crystals", chance = 100000},\n\t\t\t\t{group = "tailor_components", chance = 500000},\n\t\t\t\t{group = "meatlump_common", chance = 5000000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 2900000},\n\t\t\t\t{group = "loot_kit_parts", chance = 1500000},\n\t\t\t\t{group = "color_crystals", chance = 100000},\n\t\t\t\t{group = "tailor_components", chance = 500000},\n\t\t\t\t{group = "meatlump_common", chance = 5000000}\n\t\t\t}',
#     '{group = "meatlump_common", chance = 5000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\meatlump_oaf.lua',
#   [('{\n\tgroups = {\n\t\t{group = "junk", chance = 4500000},\n\t\t{group = "loot_kit_parts", chance = 1000000},\n\t\t--{group = "color_crystals", chance = 100000},\n\t\t{group = "tailor_components", chance = 500000},\n\t\t{group = "meatlump_common", chance = 3500000},\n\t\t--{group = "armor_attachments", chance = 5000000},\n\t\t{group = "clothing_attachments", chance = 500000},\n\t}\n}',
#     '{\n\t\t{group = "junk", chance = 4500000},\n\t\t{group = "loot_kit_parts", chance = 1000000},\n\t\t--{group = "color_crystals", chance = 100000},\n\t\t{group = "tailor_components", chance = 500000},\n\t\t{group = "meatlump_common", chance = 3500000},\n\t\t--{group = "armor_attachments", chance = 5000000},\n\t\t{group = "clothing_attachments", chance = 500000},\n\t}',
#     '{group = "clothing_attachments", chance = 500000}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 2900000},\n\t\t\t\t{group = "loot_kit_parts", chance = 1500000},\n\t\t\t\t{group = "color_crystals", chance = 100000},\n\t\t\t\t{group = "tailor_components", chance = 500000},\n\t\t\t\t{group = "meatlump_common", chance = 5000000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 2900000},\n\t\t\t\t{group = "loot_kit_parts", chance = 1500000},\n\t\t\t\t{group = "color_crystals", chance = 100000},\n\t\t\t\t{group = "tailor_components", chance = 500000},\n\t\t\t\t{group = "meatlump_common", chance = 5000000}\n\t\t\t}',
#     '{group = "meatlump_common", chance = 5000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\meatlump_stooge.lua',
#   [('{\n\t\tgroups = {\n\t\t\t{group = "junk", chance = 4500000},\n\t\t\t{group = "loot_kit_parts", chance = 1000000},\n\t\t\t--{group = "color_crystals", chance = 100000},\n\t\t\t{group = "tailor_components", chance = 500000},\n\t\t\t{group = "meatlump_common", chance = 3500000},\n\t\t\t--{group = "armor_attachments", chance = 5000000},\n\t\t\t{group = "clothing_attachments", chance = 500000},\n\t\t}\n\t}',
#     '{\n\t\t\t{group = "junk", chance = 4500000},\n\t\t\t{group = "loot_kit_parts", chance = 1000000},\n\t\t\t--{group = "color_crystals", chance = 100000},\n\t\t\t{group = "tailor_components", chance = 500000},\n\t\t\t{group = "meatlump_common", chance = 3500000},\n\t\t\t--{group = "armor_attachments", chance = 5000000},\n\t\t\t{group = "clothing_attachments", chance = 500000},\n\t\t}',
#     '{group = "clothing_attachments", chance = 500000}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 2900000},\n\t\t\t\t{group = "loot_kit_parts", chance = 1500000},\n\t\t\t\t{group = "color_crystals", chance = 100000},\n\t\t\t\t{group = "tailor_components", chance = 500000},\n\t\t\t\t{group = "meatlump_common", chance = 5000000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 2900000},\n\t\t\t\t{group = "loot_kit_parts", chance = 1500000},\n\t\t\t\t{group = "color_crystals", chance = 100000},\n\t\t\t\t{group = "tailor_components", chance = 500000},\n\t\t\t\t{group = "meatlump_common", chance = 5000000}\n\t\t\t}',
#     '{group = "meatlump_common", chance = 5000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\monumenter_marauder.lua',
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 3500000},\n\t\t\t\t{group = "wearables_common", chance = 2000000},\n\t\t\t\t{group = "rifles", chance = 1000000},\n\t\t\t\t{group = "pistols", chance = 1000000},\n\t\t\t\t{group = "melee_weapons", chance = 1000000},\n\t\t\t\t{group = "carbines", chance = 500000 },\n\t\t\t\t{group = "art_illum23", chance = 1000000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 3500000},\n\t\t\t\t{group = "wearables_common", chance = 2000000},\n\t\t\t\t{group = "rifles", chance = 1000000},\n\t\t\t\t{group = "pistols", chance = 1000000},\n\t\t\t\t{group = "melee_weapons", chance = 1000000},\n\t\t\t\t{group = "carbines", chance = 500000 },\n\t\t\t\t{group = "art_illum23", chance = 1000000}\n\t\t\t}',
#     '{group = "art_illum23", chance = 1000000}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 4000000},\n\t\t\t\t{group = "wearables_common", chance = 2000000},\n\t\t\t\t{group = "rifles", chance = 1000000},\n\t\t\t\t{group = "pistols", chance = 1000000},\n\t\t\t\t{group = "melee_weapons", chance = 1000000},\n\t\t\t\t{group = "carbines", chance = 1000000},\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 4000000},\n\t\t\t\t{group = "wearables_common", chance = 2000000},\n\t\t\t\t{group = "rifles", chance = 1000000},\n\t\t\t\t{group = "pistols", chance = 1000000},\n\t\t\t\t{group = "melee_weapons", chance = 1000000},\n\t\t\t\t{group = "carbines", chance = 1000000},\n\t\t\t}',
#     '{group = "carbines", chance = 1000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\monumenter_smuggler.lua',
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "slicing_station_group", chance = 100 * (100000)}\n\t\t\t},\n\t\t\tlootChance = 4 * (100000)\n\t\t}',
#     '{\n\t\t\t\t{group = "slicing_station_group", chance = 100 * (100000)}\n\t\t\t}',
#     '{group = "slicing_station_group", chance = 100 * (100000)}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 4000000},\n\t\t\t\t{group = "wearables_common", chance = 2000000},\n\t\t\t\t{group = "rifles", chance = 1000000},\n\t\t\t\t{group = "pistols", chance = 1000000},\n\t\t\t\t{group = "melee_weapons", chance = 1000000},\n\t\t\t\t{group = "carbines", chance = 1000000},\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 4000000},\n\t\t\t\t{group = "wearables_common", chance = 2000000},\n\t\t\t\t{group = "rifles", chance = 1000000},\n\t\t\t\t{group = "pistols", chance = 1000000},\n\t\t\t\t{group = "melee_weapons", chance = 1000000},\n\t\t\t\t{group = "carbines", chance = 1000000},\n\t\t\t}',
#     '{group = "carbines", chance = 1000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\ragtag_mercenary.lua',
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 2000000},\n\t\t\t\t{group = "wearables_common", chance = 3000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 1500000},\n\t\t\t\t{group = "power_crystals", chance = 500000},\n\t\t\t\t{group = "tailor_components", chance = 1000000},\n\t\t\t\t{group = "art_illum21", chance = 2000000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 2000000},\n\t\t\t\t{group = "wearables_common", chance = 3000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 1500000},\n\t\t\t\t{group = "power_crystals", chance = 500000},\n\t\t\t\t{group = "tailor_components", chance = 1000000},\n\t\t\t\t{group = "art_illum21", chance = 2000000}\n\t\t\t}',
#     '{group = "art_illum21", chance = 2000000}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 4000000},\n\t\t\t\t{group = "wearables_common", chance = 3000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 1500000},\n\t\t\t\t{group = "power_crystals", chance = 500000},\n\t\t\t\t{group = "tailor_components", chance = 1000000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 4000000},\n\t\t\t\t{group = "wearables_common", chance = 3000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 1500000},\n\t\t\t\t{group = "power_crystals", chance = 500000},\n\t\t\t\t{group = "tailor_components", chance = 1000000}\n\t\t\t}',
#     '{group = "tailor_components", chance = 1000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\swooper_leader.lua',
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 3300000},\n\t\t\t\t{group = "loot_kit_parts", chance = 500000},\n\t\t\t\t{group = "tailor_components", chance = 1500000},\n\t\t\t\t{group = "printer_parts", chance = 1000000},\n\t\t\t\t{group = "swooper_common", chance = 2000000},\n\t\t\t\t{group = "art_illum16", chance = 1700000 }\n\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 3300000},\n\t\t\t\t{group = "loot_kit_parts", chance = 500000},\n\t\t\t\t{group = "tailor_components", chance = 1500000},\n\t\t\t\t{group = "printer_parts", chance = 1000000},\n\t\t\t\t{group = "swooper_common", chance = 2000000},\n\t\t\t\t{group = "art_illum16", chance = 1700000 }\n\n\t\t\t}',
#     '{group = "art_illum16", chance = 1700000 }')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 3500000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1500000},\n\t\t\t\t{group = "printer_parts", chance = 1000000},\n\t\t\t\t{group = "swooper_common", chance = 2000000}\n\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 3500000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1500000},\n\t\t\t\t{group = "printer_parts", chance = 1000000},\n\t\t\t\t{group = "swooper_common", chance = 2000000}\n\n\t\t\t}',
#     '{group = "swooper_common", chance = 2000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\corellia\\zealot_of_lord_nyax.lua',
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "combat_practice", chance = 100 * (100000)}\n\t\t\t},\n\t\t\tlootChance = 25 * (100000)\n\t\t}',
#     '{\n\t\t\t\t{group = "combat_practice", chance = 100 * (100000)}\n\t\t\t}',
#     '{group = "combat_practice", chance = 100 * (100000)}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 7000000},\n\t\t\t\t{group = "pistols", chance = 1000000},\n\t\t\t\t{group = "rifles", chance = 1000000},\n\t\t\t\t{group = "carbines", chance = 1000000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 7000000},\n\t\t\t\t{group = "pistols", chance = 1000000},\n\t\t\t\t{group = "rifles", chance = 1000000},\n\t\t\t\t{group = "carbines", chance = 1000000}\n\t\t\t}',
#     '{group = "carbines", chance = 1000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\custom_content\\talus\\binayre_hooligan.lua',
# ...
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "art_forcewithyou1", chance = 10000000}\n\t\t\t},\n\t\t\tlootChance = 300000\n\t\t}',
#     '{\n\t\t\t\t{group = "art_forcewithyou1", chance = 10000000}\n\t\t\t}',
#     '{group = "art_forcewithyou1", chance = 10000000}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "holocron_dark", chance = 600000},\n\t\t\t\t{group = "holocron_light", chance = 600000},\n\t\t\t\t{group = "power_crystals", chance = 600000},\n\t\t\t\t{group = "rifles", chance = 1300000},\n\t\t\t\t{group = "pistols", chance = 1300000},\n\t\t\t\t{group = "melee_weapons", chance = 1300000},\n\t\t\t\t{group = "armor_attachments", chance = 1100000},\n\t\t\t\t{group = "clothing_attachments", chance = 1100000},\n\t\t\t\t{group = "carbines", chance = 1300000},\n\t\t\t\t{group = "dark_jedi_common", chance = 800000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "holocron_dark", chance = 600000},\n\t\t\t\t{group = "holocron_light", chance = 600000},\n\t\t\t\t{group = "power_crystals", chance = 600000},\n\t\t\t\t{group = "rifles", chance = 1300000},\n\t\t\t\t{group = "pistols", chance = 1300000},\n\t\t\t\t{group = "melee_weapons", chance = 1300000},\n\t\t\t\t{group = "armor_attachments", chance = 1100000},\n\t\t\t\t{group = "clothing_attachments", chance = 1100000},\n\t\t\t\t{group = "carbines", chance = 1300000},\n\t\t\t\t{group = "dark_jedi_common", chance = 800000}\n\t\t\t}',
#     '{group = "dark_jedi_common", chance = 800000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\thug\\mercenary.lua',
#   [('', '', '')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 10000000},\n\t\t\t},\n\t\t\tlootChance = 5000000\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 10000000},\n\t\t\t}',
#     '{group = "junk", chance = 10000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\thug\\pirate_armsman.lua',
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 3000000},\n\t\t\t\t{group = "wearables_common", chance = 2000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000},\n\t\t\t\t{group = "armor_attachments", chance = 1000000},\n\t\t\t\t{group = "clothing_attachments", chance = 1000000},\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 3000000},\n\t\t\t\t{group = "wearables_common", chance = 2000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000},\n\t\t\t\t{group = "armor_attachments", chance = 1000000},\n\t\t\t\t{group = "clothing_attachments", chance = 1000000},\n\t\t\t}',
#     '{group = "clothing_attachments", chance = 1000000}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 4000000},\n\t\t\t\t{group = "wearables_common", chance = 3000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000},\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 4000000},\n\t\t\t\t{group = "wearables_common", chance = 3000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000},\n\t\t\t}',
#     '{group = "tailor_components", chance = 1000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\thug\\pirate_leader.lua',
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 3000000},\n\t\t\t\t{group = "wearables_common", chance = 3000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 1000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000},\n\t\t\t\t{group = "armor_attachments", chance = 1000000},\n\t\t\t\t{group = "clothing_attachments", chance = 1000000},\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 3000000},\n\t\t\t\t{group = "wearables_common", chance = 3000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 1000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000},\n\t\t\t\t{group = "armor_attachments", chance = 1000000},\n\t\t\t\t{group = "clothing_attachments", chance = 1000000},\n\t\t\t}',
#     '{group = "clothing_attachments", chance = 1000000}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 4000000},\n\t\t\t\t{group = "wearables_common", chance = 3000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000},\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 4000000},\n\t\t\t\t{group = "wearables_common", chance = 3000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 2000000},\n\t\t\t\t{group = "tailor_components", chance = 1000000},\n\t\t\t}',
#     '{group = "tailor_components", chance = 1000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\thug\\smuggler.lua',
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "slicing_station_group", chance = 100 * (100000)}\n\t\t\t},\n\t\t\tlootChance = 3 * (100000)\n\t\t}',
#     '{\n\t\t\t\t{group = "slicing_station_group", chance = 100 * (100000)}\n\t\t\t}',
#     '{group = "slicing_station_group", chance = 100 * (100000)}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 4000000},\n\t\t\t\t{group = "wearables_common", chance = 2000000},\n\t\t\t\t{group = "rifles", chance = 1000000},\n\t\t\t\t{group = "pistols", chance = 1000000},\n\t\t\t\t{group = "melee_weapons", chance = 1000000},\n\t\t\t\t{group = "carbines", chance = 1000000},\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 4000000},\n\t\t\t\t{group = "wearables_common", chance = 2000000},\n\t\t\t\t{group = "rifles", chance = 1000000},\n\t\t\t\t{group = "pistols", chance = 1000000},\n\t\t\t\t{group = "melee_weapons", chance = 1000000},\n\t\t\t\t{group = "carbines", chance = 1000000},\n\t\t\t}',
#     '{group = "carbines", chance = 1000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\townsperson\\commoner_technician.lua',
#   [('', '', '')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 10000000},\n\t\t\t},\n\t\t\tlootChance = 5000000\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 10000000},\n\t\t\t}',
#     '{group = "junk", chance = 10000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\yavin4\\hooded_crystal_snake.lua',
#   [('', '', ''),
#    ('{\n\t\t\tgroups = {\n\t\t\t\t{group = "small_generic_windowed_house_s02_group", chance = 10000000}\n\t\t\t},\n\t\t\tlootChance = 350000 -- 3.5% chance for this loot group.   It should be approximately 10.1% chance for group of 3 boss mobs.\n\t\t}',
#     '{\n\t\t\t\t{group = "small_generic_windowed_house_s02_group", chance = 10000000}\n\t\t\t}',
#     '{group = "small_generic_windowed_house_s02_group", chance = 10000000}')],
#   [('', '', '')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\yavin4\\hutt_expeditionary_force_surveyor.lua',
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "art_illum19", chance = 10000000}\n\t\t\t},\n\t\t\tlootChance = 3500000\n\t\t}',
#     '{\n\t\t\t\t{group = "art_illum19", chance = 10000000}\n\t\t\t}',
#     '{group = "art_illum19", chance = 10000000}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 3400000},\n\t\t\t\t{group = "tailor_components", chance = 1000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 1000000},\n\t\t\t\t{group = "color_crystals", chance = 200000},\n\t\t\t\t{group = "power_crystals", chance = 200000},\n\t\t\t\t{group = "pistols", chance = 600000},\n\t\t\t\t{group = "carbines", chance = 600000},\n\t\t\t\t{group = "rifles", chance = 600000},\n\t\t\t\t{group = "clothing_attachments", chance = 200000},\n\t\t\t\t{group = "armor_attachments", chance = 200000},\n\t\t\t\t{group = "hutt_exp_common", chance = 2000000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 3400000},\n\t\t\t\t{group = "tailor_components", chance = 1000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 1000000},\n\t\t\t\t{group = "color_crystals", chance = 200000},\n\t\t\t\t{group = "power_crystals", chance = 200000},\n\t\t\t\t{group = "pistols", chance = 600000},\n\t\t\t\t{group = "carbines", chance = 600000},\n\t\t\t\t{group = "rifles", chance = 600000},\n\t\t\t\t{group = "clothing_attachments", chance = 200000},\n\t\t\t\t{group = "armor_attachments", chance = 200000},\n\t\t\t\t{group = "hutt_exp_common", chance = 2000000}\n\t\t\t}',
#     '{group = "hutt_exp_common", chance = 2000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\yavin4\\hutt_expeditonary_force_leader.lua',
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "airstrike_group", chance = 100 * (100000)},\n\t\t\t},\n\t\t\tlootChance = 1 * (50000), -- very rare drop\n\t\t}',
#     '{\n\t\t\t\t{group = "airstrike_group", chance = 100 * (100000)},\n\t\t\t}',
#     '{group = "airstrike_group", chance = 100 * (100000)}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 3400000},\n\t\t\t\t{group = "tailor_components", chance = 1000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 1000000},\n\t\t\t\t{group = "color_crystals", chance = 200000},\n\t\t\t\t{group = "power_crystals", chance = 200000},\n\t\t\t\t{group = "pistols", chance = 600000},\n\t\t\t\t{group = "carbines", chance = 600000},\n\t\t\t\t{group = "rifles", chance = 600000},\n\t\t\t\t{group = "clothing_attachments", chance = 200000},\n\t\t\t\t{group = "armor_attachments", chance = 200000},\n\t\t\t\t{group = "hutt_exp_common", chance = 2000000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 3400000},\n\t\t\t\t{group = "tailor_components", chance = 1000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 1000000},\n\t\t\t\t{group = "color_crystals", chance = 200000},\n\t\t\t\t{group = "power_crystals", chance = 200000},\n\t\t\t\t{group = "pistols", chance = 600000},\n\t\t\t\t{group = "carbines", chance = 600000},\n\t\t\t\t{group = "rifles", chance = 600000},\n\t\t\t\t{group = "clothing_attachments", chance = 200000},\n\t\t\t\t{group = "armor_attachments", chance = 200000},\n\t\t\t\t{group = "hutt_exp_common", chance = 2000000}\n\t\t\t}',
#     '{group = "hutt_exp_common", chance = 2000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\yavin4\\hutt_expeditonary_force_member.lua',
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "combat_practice", chance = 100 * (100000)}\n\t\t\t},\n\t\t\tlootChance = 25 * (100000)\n\t\t}',
#     '{\n\t\t\t\t{group = "combat_practice", chance = 100 * (100000)}\n\t\t\t}',
#     '{group = "combat_practice", chance = 100 * (100000)}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "junk", chance = 3400000},\n\t\t\t\t{group = "tailor_components", chance = 1000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 1000000},\n\t\t\t\t{group = "color_crystals", chance = 200000},\n\t\t\t\t{group = "power_crystals", chance = 200000},\n\t\t\t\t{group = "pistols", chance = 600000},\n\t\t\t\t{group = "carbines", chance = 600000},\n\t\t\t\t{group = "rifles", chance = 600000},\n\t\t\t\t{group = "clothing_attachments", chance = 200000},\n\t\t\t\t{group = "armor_attachments", chance = 200000},\n\t\t\t\t{group = "hutt_exp_common", chance = 2000000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "junk", chance = 3400000},\n\t\t\t\t{group = "tailor_components", chance = 1000000},\n\t\t\t\t{group = "loot_kit_parts", chance = 1000000},\n\t\t\t\t{group = "color_crystals", chance = 200000},\n\t\t\t\t{group = "power_crystals", chance = 200000},\n\t\t\t\t{group = "pistols", chance = 600000},\n\t\t\t\t{group = "carbines", chance = 600000},\n\t\t\t\t{group = "rifles", chance = 600000},\n\t\t\t\t{group = "clothing_attachments", chance = 200000},\n\t\t\t\t{group = "armor_attachments", chance = 200000},\n\t\t\t\t{group = "hutt_exp_common", chance = 2000000}\n\t\t\t}',
#     '{group = "hutt_exp_common", chance = 2000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\yavin4\\kliknik_defender.lua',
#   [('{\n\t        groups = {\n\t\t\t\t{group = "kliknik_common", chance = 10000000}\n\t\t\t},\n\t\t\tlootChance = 1540000\n\t\t}',
#     '{\n\t\t\t\t{group = "kliknik_common", chance = 10000000}\n\t\t\t}',
#     '{group = "kliknik_common", chance = 10000000}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "kliknik_common", chance = 10000000}\n\t\t\t},\n\t\t\tlootChance = 1540000\n\t\t}',
#     '{\n\t\t\t\t{group = "kliknik_common", chance = 10000000}\n\t\t\t}',
#     '{group = "kliknik_common", chance = 10000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\yavin4\\stranded_imperial_soldier.lua',
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "combat_practice", chance = 100 * (100000)}\n\t\t\t},\n\t\t\tlootChance = 25 * (100000)\n\t\t}',
#     '{\n\t\t\t\t{group = "combat_practice", chance = 100 * (100000)}\n\t\t\t}',
#     '{group = "combat_practice", chance = 100 * (100000)}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "color_crystals", chance = 100000},\n\t\t\t\t{group = "junk", chance = 4700000},\n\t\t\t\t{group = "rifles", chance = 1000000},\n\t\t\t\t{group = "pistols", chance = 1000000},\n\t\t\t\t{group = "melee_weapons", chance = 1000000},\n\t\t\t\t{group = "carbines", chance = 1000000},\n\t\t\t\t{group = "clothing_attachments", chance = 100000},\n\t\t\t\t{group = "armor_attachments", chance = 100000},\n\t\t\t\t{group = "wearables_common", chance = 1000000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "color_crystals", chance = 100000},\n\t\t\t\t{group = "junk", chance = 4700000},\n\t\t\t\t{group = "rifles", chance = 1000000},\n\t\t\t\t{group = "pistols", chance = 1000000},\n\t\t\t\t{group = "melee_weapons", chance = 1000000},\n\t\t\t\t{group = "carbines", chance = 1000000},\n\t\t\t\t{group = "clothing_attachments", chance = 100000},\n\t\t\t\t{group = "armor_attachments", chance = 100000},\n\t\t\t\t{group = "wearables_common", chance = 1000000}\n\t\t\t}',
#     '{group = "wearables_common", chance = 1000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\yavin4\\stranded_rebel_soldier.lua',
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "combat_practice", chance = 100 * (100000)}\n\t\t\t},\n\t\t\tlootChance = 25 * (100000)\n\t\t}',
#     '{\n\t\t\t\t{group = "combat_practice", chance = 100 * (100000)}\n\t\t\t}',
#     '{group = "combat_practice", chance = 100 * (100000)}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "color_crystals", chance = 100000},\n\t\t\t\t{group = "junk", chance = 4700000},\n\t\t\t\t{group = "rifles", chance = 1000000},\n\t\t\t\t{group = "pistols", chance = 1000000},\n\t\t\t\t{group = "melee_weapons", chance = 1000000},\n\t\t\t\t{group = "carbines", chance = 1000000},\n\t\t\t\t{group = "clothing_attachments", chance = 100000},\n\t\t\t\t{group = "armor_attachments", chance = 100000},\n\t\t\t\t{group = "wearables_common", chance = 1000000}\n\t\t\t}\n\t\t}',
#     '{\n\t\t\t\t{group = "color_crystals", chance = 100000},\n\t\t\t\t{group = "junk", chance = 4700000},\n\t\t\t\t{group = "rifles", chance = 1000000},\n\t\t\t\t{group = "pistols", chance = 1000000},\n\t\t\t\t{group = "melee_weapons", chance = 1000000},\n\t\t\t\t{group = "carbines", chance = 1000000},\n\t\t\t\t{group = "clothing_attachments", chance = 100000},\n\t\t\t\t{group = "armor_attachments", chance = 100000},\n\t\t\t\t{group = "wearables_common", chance = 1000000}\n\t\t\t}',
#     '{group = "wearables_common", chance = 1000000}')]],
#  ['C:\\Users\\micha\\Documents\\source\\wun1\\MMOCoreORB\\bin\\scripts\\mobile\\\\yavin4\\swarming_kliknik.lua',
#   [('{\n\t        groups = {\n\t\t\t\t{group = "kliknik_common", chance = 10000000}\n\t\t\t},\n\t\t\tlootChance = 1200000\n\t\t}',
#     '{\n\t\t\t\t{group = "kliknik_common", chance = 10000000}\n\t\t\t}',
#     '{group = "kliknik_common", chance = 10000000}')],
#   [('{\n\t\t\tgroups = {\n\t\t\t\t{group = "kliknik_common", chance = 10000000}\n\t\t\t},\n\t\t\tlootChance = 1200000\n\t\t}',
#     '{\n\t\t\t\t{group = "kliknik_common", chance = 10000000}\n\t\t\t}',
#     '{group = "kliknik_common", chance = 10000000}')]]]
